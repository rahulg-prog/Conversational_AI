# %%
import os
from dotenv import load_dotenv
from elevenlabs.client import ElevenLabs

load_dotenv()

client = ElevenLabs(
    api_key=os.getenv("ELEVENLABS_API_KEY")
)

response = client.conversational_ai.agents.get(agent_id="agent_1801ke6gspgzentb8rcbkxbkten5")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 11
#       5 load_dotenv()
#       7 client = ElevenLabs(
#       8     api_key=os.getenv("ELEVENLABS_API_KEY")
#       9 )
# ---> 11 response = client.conversational_ai.agents.get()
#
# TypeError: AgentsClient.get() missing 1 required positional argument: 'agent_id'

# %%
response
# Out:
# GetAgentsPageResponseModel(agents=[AgentSummaryResponseModel(agent_id='agent_1801ke6gspgzentb8rcbkxbkten5', name='virali agent', tags=[], created_at_unix_secs=1767597989, access_info=ResourceAccessInfo(is_creator=True, creator_name='Rahul G | Webknot', creator_email='rahul.g@webknot.in', role='admin'), last_call_time_unix_secs=None, archived=False)], next_cursor=None, has_more=False)
